# %% [markdown]
# Nombre: Juan Felipe Zamudio D.
# programa : Ingenieria Ambiental
# ¿Como puede la programacion apoyar la ingenieria ambiental?
# Gracias a la programacion podemos analizar ciertos datos ambientales los cuales abarquen por ejemplo a temas de calidades, ya sea de agua o aire, y con esto nos facilita a la hora de tomar desiciones tecnicas basadas en los datos los cuales nos arrogen la progrmacion para hacer lo mas optimo

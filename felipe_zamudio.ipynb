# %% [markdown]
# Juan Felipe Zamudio D.
# Programa de ingenieria ambiental
# La programación se ha convertido en una herramienta fundamental en la ingeniería ambiental porque permite transformar grandes volúmenes de datos en información útil para la toma de decisiones. En un contexto donde los sistemas naturales son complejos y dinámicos, la capacidad de modelar, simular y analizar procesos ambientales resulta clave para comprender fenómenos como el cambio climático, la contaminación del agua o la dispersión de contaminantes en el aire.

# %%
mensaje = "Un enfoque profesional en la ingeniería ambiental integra la calidad del agua, la gestión de residuos, el cambio climático, la conservación de ecosistemas y las energías renovables para lograr un desarrollo sostenible basado en decisiones técnicas responsables."

print(mensaje)
# Out:
# Un enfoque profesional en la ingeniería ambiental integra la calidad del agua, la gestión de residuos, el cambio climático, la conservación de ecosistemas y las energías renovables para lograr un desarrollo sostenible basado en decisiones técnicas responsables.
